# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Bangalore.csv')
city_bangalore = ['Bangalore' for i in range(len(df1))]
len(city_bangalore)
df1['city'] = city_bangalore

# %%
df2 = pd.read_csv('Chennai.csv')
city_chennai = ['Chennai' for i in range(len(df2))]
len(city_chennai)
df2['city'] = city_chennai

# %%
df3 = pd.read_csv('Delhi.csv')
city_delhi = ['Delhi' for i in range(len(df3))]
len(city_delhi)
df3['city'] = city_delhi

# %%
df4 = pd.read_csv('Hyderabad.csv')
city_hyderabad = ['Hyderabad' for i in range(len(df4))]
len(city_hyderabad)
df4['city'] = city_hyderabad

# %%
df5 = pd.read_csv('Kolkata.csv')
city_kolkata = ['Kolkata' for i in range(len(df5))]
len(city_kolkata)
df5['city'] = city_kolkata

# %%
df6 = pd.read_csv('Mumbai.csv')
city_mumbai = ['Mumbai' for i in range(len(df6))]
len(city_mumbai)
df6['city'] = city_mumbai

# %%
df1.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df2.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df3.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df4.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df5.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df6.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
len(df1)
# Out:
# 6207

# %%
len(df2)
# Out:
# 5014

# %%
len(df3)
# Out:
# 4998

# %%
len(df4)
# Out:
# 2518

# %%
len(df5)
# Out:
# 6507

# %%
len(df6)
# Out:
# 7719

# %%
df_main = pd.concat([df1, df2])

# %%
len(df_main)
# Out:
# 11221

# %%
df_main = pd.concat([df_main, df3])

# %%
df_main = pd.concat([df_main, df4])

# %%
df_main = pd.concat([df_main, df5])

# %%
df_main = pd.concat([df_main, df6])

# %%
len(df_main)
# Out:
# 32963

# %%
from sklearn.utils import shuffle as sf

df = sf(df_main)

# %%
df
# Out:
#          Price  Area      Location  No. of Bedrooms  Resale  MaintenanceStaff  \
# 5717   4788000  1501   New Alipore                3       0                 9
# 7320  13700000   808    Thane West                2       0                 9
# 7425  11000000  1150          Ulwe                3       1                 9
# 142   16500000  2630    Karapakkam                4       0                 0
# 5797  20800000  1070      Sonarpur                2       0                 9
# ...        ...   ...           ...              ...     ...               ...
# 4809   3200000   450       Munirka                1       1                 9
# 4913   3001000  1590      Sonarpur                3       0                 9
# 4186   4200000   800  Chingrighata                2       0                 9
# 6275   8600000  1097      Sonarpur                3       0                 9
# 1608   2110000   900     Khar West                2       1                 9
#
# ...

# %%
df.reset_index()
# Out:
#        index     Price  Area      Location  No. of Bedrooms  Resale  \
# 0       5717   4788000  1501   New Alipore                3       0
# 1       7320  13700000   808    Thane West                2       0
# 2       7425  11000000  1150          Ulwe                3       1
# 3        142  16500000  2630    Karapakkam                4       0
# 4       5797  20800000  1070      Sonarpur                2       0
# ...      ...       ...   ...           ...              ...     ...
# 32958   4809   3200000   450       Munirka                1       1
# 32959   4913   3001000  1590      Sonarpur                3       0
# 32960   4186   4200000   800  Chingrighata                2       0
# 32961   6275   8600000  1097      Sonarpur                3       0
# 32962   1608   2110000   900     Khar West                2       1
#
#        MaintenanceStaff  Gymnasium  SwimmingPool  LandscapedGardens  ...  BED  \
# ...

# %%
df.columns
# Out:
# Index(['Price', 'Area', 'Location', 'No. of Bedrooms', 'Resale',
#        'MaintenanceStaff', 'Gymnasium', 'SwimmingPool', 'LandscapedGardens',
#        'JoggingTrack', 'RainWaterHarvesting', 'IndoorGames', 'ShoppingMall',
#        'Intercom', 'SportsFacility', 'ATM', 'ClubHouse', 'School',
#        '24X7Security', 'PowerBackup', 'CarParking', 'StaffQuarter',
#        'Cafeteria', 'MultipurposeRoom', 'Hospital', 'WashingMachine',
#        'Gasconnection', 'AC', 'Wifi', 'Children'splayarea', 'LiftAvailable',
#        'BED', 'VaastuCompliant', 'Microwave', 'GolfCourse', 'TV',
#        'DiningTable', 'Sofa', 'Wardrobe', 'Refrigerator', 'city'],
#       dtype='object')

# %%
df.to_csv('Main.csv', index=True)
